# %%
#| hide
from agent_chatbot.app import *

# %% [markdown]
# # agent_chatbot
#
# > Agentic chat bot test using pydantic-ai

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install agent_chatbot in Development mode

# %% [markdown]
# ```sh
# # make sure agent_chatbot package is installed in development mode
# $ pip install -e ."[dev]"
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to agent_chatbot
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/redam94/agent_chatbot.git
# ```
#
#
# [repo]: https://github.com/redam94/agent_chatbot
# [docs]: https://redam94.github.io/agent_chatbot/
# [pypi]: https://pypi.org/project/agent_chatbot/
# [conda]: https://anaconda.org/redam94/agent_chatbot

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/redam94/agent_chatbot
# [docs]: https://redam94.github.io/agent_chatbot/
# [pypi]: https://pypi.org/project/agent_chatbot/
# [conda]: https://anaconda.org/redam94/agent_chatbot
