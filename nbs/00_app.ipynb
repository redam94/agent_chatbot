# %% [markdown]
# # App
#
# > Main code for running agent chatbot API

# %%
#| default_exp app

# %%
#| export
import pydantic_ai

# %%
#| hide
from nbdev.showdoc import *

# %%
#| hide
import nbdev; nbdev.nbdev_export()
